# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
#importing CSV file
df = pd.read_csv('C:\\Users\\sinch\\Downloads\\jupyter notebook\\Diwali_sales_data.csv', encoding='latin1')

# %%
df.shape
# Out:
# (99, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           99 non-null     int64
#  1   Cust_name         99 non-null     object
#  2   Product_ID        99 non-null     object
#  3   Gender            99 non-null     object
#  4   Age Group         99 non-null     object
#  5   Age               99 non-null     int64
#  6   Marital_Status    99 non-null     int64
#  7   State             99 non-null     object
#  8   Zone              99 non-null     object
#  9   Occupation        99 non-null     object
#  10  Product_Category  99 non-null     object
#  11  Orders            99 non-null     int64
#  12  Amount            96 non-null     float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 11.7+ KB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           99 non-null     int64
#  1   Cust_name         99 non-null     object
#  2   Product_ID        99 non-null     object
#  3   Gender            99 non-null     object
#  4   Age Group         99 non-null     object
#  5   Age               99 non-null     int64
#  6   Marital_Status    99 non-null     int64
#  7   State             99 non-null     object
#  8   Zone              99 non-null     object
#  9   Occupation        99 non-null     object
#  10  Product_Category  99 non-null     object
#  11  Orders            99 non-null     int64
#  12  Amount            96 non-null     float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 10.2+ KB

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              3
# dtype: int64

# %%
df.shape
# Out:
# (99, 13)

# %%
# drop null values
df.dropna(inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#     User_ID   Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0   1002903   Sanskriti  P00125942      F     26-35   28       0
# 1   1000732      Kartik  P00110942      F     26-35   35       1
# 2   1001990       Bindu  P00118542      F     26-35   35       1
# 3   1001425      Sudevi  P00237842      M      0-17   16       0
# 4   1000588        Joni  P00057942      M     26-35   28       1
# ..      ...         ...        ...    ...       ...  ...     ...
# 94  1002165       Black  P00260442      F     26-35   31       1
# 95  1004416       Airdo  P00213742      F     18-25   23       0
# 96  1000850      Bhawna  P00319942      F     36-45   44       0
# 97  1002888  Corey-Lock  P00255842      F     26-35   34       0
# 98  1001891        Akin  P00192542      F     46-50   46       0
#
#              State      Zone       Occupation  Product_Category  Orders  \
# 0      Maharashtra   Western       Healthcare              Auto       1
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID        Age  Marital_Status     Orders        Amount
# count  9.600000e+01  96.000000       96.000000  96.000000     96.000000
# mean   1.002638e+06  34.666667        0.489583   2.395833  22310.927083
# std    1.753956e+03  11.989176        0.502516   1.128382   1194.953575
# min    1.000113e+06  16.000000        0.000000   1.000000  20929.000000
# 25%    1.001183e+06  26.000000        0.000000   1.000000  21053.250000
# 50%    1.002440e+06  34.000000        0.000000   2.000000  22305.000000
# 75%    1.004095e+06  40.000000        1.000000   3.000000  23452.250000
# max    1.006040e+06  83.000000        1.000000   4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#              Age     Orders        Amount
# count  96.000000  96.000000     96.000000
# mean   34.666667   2.395833  22310.927083
# std    11.989176   1.128382   1194.953575
# min    16.000000   1.000000  20929.000000
# 25%    26.000000   1.000000  21053.250000
# 50%    34.000000   2.000000  22305.000000
# 75%    40.000000   3.000000  23452.250000
# max    83.000000   4.000000  23952.000000

# %%
# 1.GENDER
# plotting a bar chart for Gender and it's count

ax=sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.histplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
#From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men

# %%
# 2.AGE
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.scatterplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
#From above graphs we can see that most of the buyers are of age group between 26-35 years female

# %%
# 3.State
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,10)})
sns.lineplot(data = sales_state, x = 'State',y= 'Orders', color="red", linewidth=2.5)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.boxplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
#From above graphs we can see that most of the orders and total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %%
# 4.Marital Status
ax = sns.countplot(data = df, x = 'Marital_Status', palette="Set2", edgecolor="green")

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_13876\3413551644.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Marital_Status', palette="Set2", edgecolor="green")

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender', edgecolor="red", palette='Set1')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
#From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %%
# 5. Occupation
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation', edgecolor="black", palette="Set3")

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_13876\1655405238.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Occupation', edgecolor="black", palette="Set3")

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.lineplot(data = sales_state, x = 'Occupation',y= 'Amount', palette="Set1", linewidth=2.5,color="green")
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_13876\1678793827.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = sales_state, x = 'Occupation',y= 'Amount', palette="Set1", linewidth=2.5,color="green")
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
#From above graphs we can see that most of the buyers are working in IT and Aviation sector

# %%
# 6. Product Category
sns.set(rc={'figure.figsize':(30,10)})
ax = sns.countplot(data = df, x = 'Product_Category', palette="Set2", edgecolor="red")

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_13876\480152641.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Product_Category', palette="Set2", edgecolor="red")

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(40,30)})
sns.violinplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
#From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders', palette="Set2", edgecolor="black")
# Out:
# C:\Users\sinch\AppData\Local\Temp\ipykernel_13876\1054716888.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders', palette="Set2", edgecolor="black")
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(20,10))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='Orders'>
